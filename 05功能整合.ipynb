# %% [markdown]
# # 功能整合
#
# 类`ChangEDataManager`，包含以下功能：
#
# - 本地数据文件夹设置、数据文件数统计、定制条件查询
# - 远程数据查询和下载
# - 载入pds文件并处理为图像数据（numpy？cv2？pyqt？）
# - 将图像数据保存为PNG，可调缩放
#
# 还未考虑好的功能：
#
# - 双目图像自动查找并返回图像数据
# - 同批次图像自动查找并镶嵌拼合
# - 全景图巡视
#
# `ChangEDataManager`是用来在后端处理数据的类，前端的`ChangEViewer`将请求发来之后，`ChangEDataManager`会将处理之后的数据（字符串、列表或图像数据）返回给`ChangEViewer`

# %% [markdown]
# ## 1. `ChangEDataManager`
#
# 由于嫦娥公开数据文件数量众多，文件名超长，所以这里专门设计了一个类`ChangEDataManager`，将数据的远程查询、下载、缓存、及本地标签查询等功能集成在一起，便于管理和访问。

# %% [markdown]
# ### 1.1 query()
#
# 新建`ChangEDataManager`的时候需要配置本地数据缓存目录。
#
# `query()`的流程：
#
# 1. 将先查询本地缓存，获得一个list；
# 2. 空查询远端服务器，获得符合条件的数据数目；
# 3. 比较本地和远端的数目，如果相同就不查询远端，如果不同，则进一步查询远端，获得远端list；
# 4. 两个list进行比较，标出区别，得出完整的lsit
# 5. 返回带标记的list

# %%
import os
import re
import requests
import time
import atool
from PIL import Image
import numpy as np
import pds4_tools
import colour
import colour_demosaicing
from skimage import exposure
import cv2

class ChangEDataManager:
    def __init__(self, path='./data'):
        """
        初始化内部变量，扫描数据文件夹，并现实初始化信息
        """
        self.__cache_path = path
        self.__data = []
        self.info()
        pass

    def scan_cache(self, with_hidden=False):
        """
        扫描数据文件夹，将文件名保存下来，并返回文件数量
        """        
        self.__data = []
        for f in os.listdir(self.__cache_path):
            if with_hidden == False and f[0] == '.':
                pass
            else:
                self.__data.append(f)
        count = len(self.__data)
        return count
    
    def info(self):
        print('嫦娥数据管理器 v0.2')
        print('数据文件目录 : %s' % (self.__cache_path))
        print('数据文件数目 ：%d' % (self.scan_cache()))
        #for f in os.listdir(self.__cache):
        #    print(f)
        pass
    
    def get_ChangE_download_link(self, pageNo, pageSize, task_id='CE4', data_type='SCI', payload='PCAM', data_grade='2B', date_start='default', date_end='today'):
        """
        通过requests.get()发起远程查询，说明详见“01下载数据”。尽量用query_remote()调用，而不是直接调用本函数。
        """
        # 默认情况下，根据任务设置查询的起始时间
        if date_start == 'default':
            if task_id == 'CE5':
                date_start = '2020-11-30 00:00:00'
            if task_id == 'CE4':
                date_start = '2019-01-02 00:00:00'
            if task_id == 'CE3':
                date_start = '2009-12-31 00:00:00'
            if task_id == 'CE2':
                date_start = '2010-10-01 00:00:00'
            if task_id == 'CE1':
                date_start = '2007-10-24 00:00:00'

        # 默认情况下，设置查询的结束时间为当天
        if date_end == 'today':
            date_end = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())

        # 组装参数
        url = 'https://' + 'moon.bao.ac.cn' + '/proSearch!proSearchList.search'
        inputJsonString = '{"globalLang":null,"DM_DTYPE":"%s","DM_TASKID":"%s","DM_ZHNAME":"%s","DM_GRADE":"%s","DM_CBTIMEStart":"%s","DM_CBTIMEend":"%s","order_by":"desc","qsList":"","qsStart":"","qsEnd":"","bianhao":""}' % (data_type, task_id, payload, data_grade, date_start, date_end)
        param = {
            '_dc': '1615623500055', 
            'pageNo': str(pageNo), 
            'pageSize': str(pageSize), 
            'inputJsonString': inputJsonString, 
            'page': str(pageNo), 
            'start': str((pageNo-1)*pageSize), 
            'limit': str(pageSize)}

        # 访问网站，查询
        r = requests.get(url, param)
        if r.ok:
            link = []
            link.append(r.json()['totalCount'])
            for data in r.json()['returndata']:
                # print(atool.pretty(data))
                # 真实的下载链接
                link.append(data['dmStorepath'].replace('/PUBDATA/', 'http://moon.bao.ac.cn/cedownload/'))

            return link
        else:
            return None
    
    def is_datafile_exist(self, filename, filebuf=None, path='.', method='name'):
        """
        检查给定的文件是否已经存在
        目前只比对文件名
        """
        path = self.__cache_path
        if method == 'name':
            for f in os.listdir(path):
                if f[0] == '.':
                    pass
                else:
                    if filename == f:
                        return True
            return False
        elif method == 'size':
            pass
        elif method == 'content':
            pass

    def download(self, url, path):
        """
        将给定的url下载到path中
        """
        def pleasant_size(size):
            if size > 1024:
                size = size/1024
                [rs, unit] = pleasant_size(size)
                if unit == 'B':
                    return [rs, 'kB']
                elif unit == 'kB':
                    return [rs, 'MB']
                elif unit == 'MB':
                    return [rs, 'GB']
                elif unit == 'TB':
                    return [rs, 'TB']
                elif unit == 'PB':
                    return [rs, 'PB']
            else:
                return [size, 'B']
        
        path = self.__cache_path
        filename = url[(url.rfind('/')+1):len(url)]

        r = requests.get(url, stream=True)

        if r.ok:
            realsize = int(r.headers['Content-Length'])
            [size, unit] = pleasant_size(realsize)
            print('开始下载 %s（%.2f %s） ' % (filename, size, unit), end='')
            finished = 0
            with open(path + '/' + filename, "wb") as data:
                for chunk in r.iter_content(chunk_size=1024):
                    if chunk:
                        data.write(chunk)
                        finished = finished + len(chunk)
                    if (finished>realsize/10):
                        print('.', end='')
                        finished=0
            data.close()
            print('完成')
        else:
            print(r, filename, '连接失败')
    
    def query_and_download_all(self, task_id='CE4', data_type='SCI', payload='PCAM', data_grade='2B', date_start='default', date_end='today'):
        # 查第0页，不会返回具体数据，但是会返回数据文件的数目
        links = self.get_ChangE_download_link(0, 10, task_id, data_type, payload, data_grade, date_start, date_end)
        if links != None:
            # 获取数据总条目
            totalcount = int(links[0])
            print('查询到数据文件共 %d 个' % (totalcount))

            print('开始下载...')

            # 每页10条数据，反复“查询-下载”
            for i in range(int(totalcount/10+1)):
                print(i+1)
                links = self.get_ChangE_download_link(i+1, 10, task_id, data_type, payload, data_grade, date_start, date_end)
                if links != None:
                        for l in links[1:len(links)]:
                            filename = l[(l.rfind('/')+1):len(l)]
                            if self.is_datafile_exist(filename, path='data'):
                                print('文件 %s 已存在' % (filename))
                            else:
                                self.download(l, 'data')
                        print('下载完成')
                        time.sleep(0.5)
    
    def query_remote(self, qtask='CE4', qseq='*', qbatch='*', qcolor='*', qsite='*', qpayload='*', qdata_type='*', qdata_grade='*', qext='*'):
        """
        get_ChangE_download_link()函数的套壳
        """
        # 处理各参数
        task_id = '' if qtask == '*' else qtask
        data_type = '' if qdata_type == '*' else qdata_type
        payload = '' if qpayload == '*' else qpayload
        data_grade = '' if qdata_grade == '*' else qdata_grade
            
        # 先查第0页，获得数据总条目
        r = get_ChangE_download_link(0, 10, task_id, data_type, payload, data_grade, date_start, date_end)
        if r == None:
            return r
        # 获取数据总条目
        totalcount = int(r[0])
        print(totalcount)
        
        # TODO:
        # 多次查询将文件名和下载链接提取出来
        # 用其他的查询条件去除多余的结果
        # 返回列表
        pass
        
    def query_local(self, qtask='CE4', qseq='*', qbatch='*', qcolor='*', qsite='*', qpayload='*', qdata_type='*', qdata_grade='*', qext='*'):
        """
        发起一次本地查询，遍历self.__data中保存的所有文件名，返回符合查询条件的文件名
        """
        def check_tag(filename, tags):
            # 数据文件名样式有如下几种：
            # CE4_GRAS_PCAML-C-000_SCI_N_20200227111928_20200227111928_0121_B.2BL
            # 匹配样式：(.*)_(.*)_(.*)-(.*)-(.*)_(.*)_(.*)_([0-9]*)_([0-9]*)_([0-9]{4})_(.*)\.(.*)
            pattern = []
            pattern.append(r'(.*)_(.*)_(.*)-(.*)-(.*)_(.*)_(.*)_([0-9]*)_([0-9]*)_([0-9]{4})_(.*)\.(.*)')
            # CE4_GRAS_ASAN-SCI_SCI_N_20190111150201_20190112102100_0003_B.2B
            # 匹配样式：(.*)_(.*)_(.*)-(.*)_(.*)_(.*)_([0-9]*)_([0-9]*)_([0-9]{4})_(.*)\.(.*)
            pattern.append(r'(.*)_(.*)_(.*)-(.*)_(.*)_(.*)_([0-9]*)_([0-9]*)_([0-9]{4})_(.*)\.(.*)')
            
            match_obj = re.match(pattern[0], filename)
            match_obj2= re.match(pattern[1], filename)
            # 提取出文件名中的各种标签
            if match_obj != None:
                task = match_obj.group(1) # 任务
                site = match_obj.group(2) # 站点
                payload = match_obj.group(3) # 载荷，如果是PCAM的话，还需要指出是左眼还是右眼
                color = match_obj.group(4) # C、Q
                seq = match_obj.group(5) # 序号
                data_type = match_obj.group(6) # 数据类型
                unknown = match_obj.group(7) # 未知
                start_time = match_obj.group(8) # 起时间
                end_time = match_obj.group(9) # 止时间
                batch = match_obj.group(10) # 序号？
                data_grade = match_obj.group(11) # 数据等级
                ext = match_obj.group(12) # 扩展名
            elif match_obj2 != None:
                task = match_obj2.group(1) # 任务
                site = match_obj2.group(2) # 站点
                payload = match_obj2.group(3) # 载荷，如果是PCAM的话，还需要指出是左眼还是右眼
                color = 'N/A' # C、Q
                seq = '-1' # 序号
                data_type = match_obj2.group(5) # 数据类型
                unknown = match_obj2.group(6) # 未知
                start_time = match_obj2.group(7) # 起时间
                end_time = match_obj2.group(8) # 止时间
                batch = match_obj2.group(9) # 序号？
                data_grade = match_obj2.group(10) # 数据等级
                ext = match_obj2.group(11) # 扩展名
            else:
                return None
                
            ftags = [task, seq, batch, color, site, payload, data_type, data_grade, ext]
            #print(ftags)
                
            # 逐个检查标签是否匹配
            checklist = []
            for i in range(len(tags)):
                t = tags[i]
                f = ftags[i]
                if t == '*':
                    checklist.append(True)
                elif t == f:
                    checklist.append(True)
                else:
                    checklist.append(False)
            return checklist
        
        result = []

        # 依次判断文件名是否满足查询
        for f in self.__data:
            checked = True
            checklist = check_tag(f, [qtask, qseq, qbatch, qcolor, qsite, qpayload, qdata_type, qdata_grade, qext])
            #print(f, checklist)
            if checklist == None:
                print('注意：文件名格式无法匹配 %s' % (f))
            else:
                for c in checklist:
                    if c == False:
                        checked = False
                        break
                if checked == True:
                    result.append(f)
        
        return sorted(result)
    
    def query(self, qtask='CE4', qseq='*', qbatch='*', qcolor='*', qsite='*', qpayload='*', qdata_type='*', qdata_grade='*', qext='*'):
        """
        统一查询。先查本地，再查远程。本地标注已缓存，远程标注下载链接
        """
        local_list = self.query_local(qtask, qseq, qbatch, qcolor, qsite, qpayload, qdata_type, qdata_grade, qext)
        remote_list= self.query_remote(qtask, qseq, qbatch, qcolor, qsite, qpayload, qdata_type, qdata_grade, qext)
        query_list=[]
        for f in remote_list:
            if f in local_list:
                query_list.append(['c', f])
            else:
                query_list.append(['download_url', f])
        print(atool.pretty(query_list))
        
    def load_2A2B(self, filename):
        """
        读入2A或2B数据，并返回处理过的、原始大小的numpy数组
        """
        img = {}

        # 读入嫦娥4号2BL数据
        img['pds_data'] = pds4_tools.read(filename)

        # 将图像数据提取出来
        img['raw_data'] = np.asanyarray(img['pds_data'][0].data)
        img['raw_data'] = img['raw_data'] / 1023      #10位的图像数据归一化
        print('提取原始数据并归一化', img['raw_data'].shape, img['raw_data'].ndim)

        # de-bayer
        rgb_data = colour.cctf_encoding(colour_demosaicing.demosaicing_CFA_Bayer_bilinear(img['raw_data'], 'RGGB')) 
        img['rgb_data'] = rgb_data
        print('CFA上色（de-bayer）', rgb_data.shape, rgb_data.ndim)

        # 直方图拉伸
        lower, upper = np.percentile(img['rgb_data'], (5,99))
        img['intensity_data'] = exposure.rescale_intensity(img['rgb_data'], in_range=(lower, upper)) 
        print('直方图拉伸', lower, upper)

        return img['intensity_data']


    def convert_pds_2_png(self, filename, scale=1.0, input_path='data', output_path='png'):
        """
        filename是包含路径的文件名
        """
        img = {}
        input_path = self.__cache_path

        img['intensity_data'] = self.load_2A2B(filename)
        print(type(img['intensity_data']))

        # 缩放
        if scale != 1.0:
            print('图像缩放', scale)
            height, width = img['intensity_data'].shape[:2]
            size = (int(width*scale), int(height*scale))  
            img['scaled_data'] = cv2.resize(img['intensity_data'], size, interpolation=cv2.INTER_AREA)
        else:
            img['scaled_data'] = img['intensity_data']

        # 保存到文件
        p = img['scaled_data'] * 255
        p = p.astype('uint8')
        output_filename = filename.replace(input_path, output_path) + '.png'
        cv2.imwrite(output_filename, cv2.cvtColor(p, cv2.COLOR_RGB2BGR)) # opencv的红色和蓝色会对调，需要改变一下颜色顺序
        print('保存到文件', output_filename)
    
    def convert_pds_from_list(self, filelist, scale=1.0, input_path='data', output_path='png'):
        input_path = self.__cache_path
        for filename in filelist:
            self.convert_pds_2_png(input_path + '/' + filename, scale, input_path, output_path) # 可设置输入目录与输出目录
            
    def convert_SBS_png(self, leftfile, rightfile):
        # 读入左右目图片
        leftimg0 = self.load_2A2B(leftfile)
        rightimg0= self.load_2A2B(rightfile)
        # 变形并调整尺寸
        size = (960, 1080)  
        leftimg1 = cv2.resize(leftimg0, size, interpolation=cv2.INTER_AREA)
        rightimg1= cv2.resize(rightimg0, size, interpolation=cv2.INTER_AREA)
        # 将两个图像合并为一
        img = np.hstack((leftimg1, rightimg1)) 
        return img

    def convert_SBS_from_list(self, leftlist, rightlist, inputpath, outputpath):
        inputpath = self.__cache_path
        for i in range(len(leftlist)):
            leftfile = inputpath + '/' + leftlist[i]
            rightfile= inputpath + '/' + rightlist[i]
            img = self.convert_SBS_png(leftfile, rightfile)
            p = img * 255
            p = p.astype('uint8')
            cv2.imwrite(outputpath+'/'+leftlist[i].replace('PCAML', 'PCAMLR')+'.png', cv2.cvtColor(p, cv2.COLOR_RGB2BGR))

# %%
cedm = ChangEDataManager('data')
# Out:
# 嫦娥数据管理器 v0.2
# 数据文件目录 : data
# 数据文件数目 ：20640

# %%
list = cedm.get_ChangE_download_link(10, 100, task_id='CE3', payload='', data_grade='', date_start='')
print(atool.pretty(list))
# Out:
# [
#     254138
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110230809_20150110230809_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110230809_20150110230809_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110230604_20150110230604_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110230604_20150110230604_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110230358_20150110230358_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110230358_20150110230358_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110230153_20150110230153_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110230153_20150110230153_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110225947_20150110225947_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110225947_20150110225947_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110225906_20150110225906_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110225906_20150110225906_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110225700_20150110225700_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110225700_20150110225700_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110225455_20150110225455_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110225455_20150110225455_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110225249_20150110225249_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110225249_20150110225249_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110225044_20150110225044_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110225044_20150110225044_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110224838_20150110224838_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110224838_20150110224838_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110224633_20150110224633_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110224633_20150110224633_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110224427_20150110224427_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110224427_20150110224427_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110224222_20150110224222_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110224222_20150110224222_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110224016_20150110224016_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110224016_20150110224016_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110223811_20150110223811_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110223811_20150110223811_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110223605_20150110223605_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110223605_20150110223605_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110223400_20150110223400_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110223400_20150110223400_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110223154_20150110223154_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110223154_20150110223154_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110222949_20150110222949_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110222949_20150110222949_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110222907_20150110222907_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110222907_20150110222907_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110222702_20150110222702_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110222702_20150110222702_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110222456_20150110222456_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110222456_20150110222456_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110222251_20150110222251_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110222251_20150110222251_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110222045_20150110222045_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110222045_20150110222045_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110221840_20150110221840_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110221840_20150110221840_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110221634_20150110221634_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110221634_20150110221634_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110221429_20150110221429_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110221429_20150110221429_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110221223_20150110221223_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110221223_20150110221223_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110221018_20150110221018_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110221018_20150110221018_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110220812_20150110220812_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110220812_20150110220812_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110220607_20150110220607_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110220607_20150110220607_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110220401_20150110220401_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110220401_20150110220401_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110220156_20150110220156_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110220156_20150110220156_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110215950_20150110215950_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110215950_20150110215950_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110215910_20150110215910_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110215910_20150110215910_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110215704_20150110215704_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110215704_20150110215704_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110215459_20150110215459_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110215459_20150110215459_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110215253_20150110215253_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110215253_20150110215253_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110215048_20150110215048_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110215048_20150110215048_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110214842_20150110214842_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110214842_20150110214842_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110214637_20150110214637_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110214637_20150110214637_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110214431_20150110214431_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110214431_20150110214431_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110214226_20150110214226_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110214226_20150110214226_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110214020_20150110214020_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110214020_20150110214020_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110213815_20150110213815_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110213815_20150110213815_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110213609_20150110213609_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110213609_20150110213609_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110213404_20150110213404_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110213404_20150110213404_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110213158_20150110213158_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110213158_20150110213158_0393_B.2B
#     http://moon.bao.ac.cn/cedownload/MUVT/2A/CE3_BMYK_MUVT-P-0099_SCI_N_20150110212953_20150110212953_0393_B.2A
#     http://moon.bao.ac.cn/cedownload/MUVT/2B/CE3_BMYK_MUVT-P-0099_SCI_N_20150110212953_20150110212953_0393_B.2B
#
# ]

# %%
cedm.query_and_download_all(task_id='CE4', payload='PCAML', data_grade='', date_start='20200401')
# Out:
# 查询到数据文件共 220 个
# 开始下载...
# 1
# 文件 CE4_GRAS_PCAML-C-011_SCI_N_20200428095013_20200428095013_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-C-011_SCI_N_20200428095013_20200428095013_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-C-010_SCI_N_20200428094844_20200428094844_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-C-010_SCI_N_20200428094844_20200428094844_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-C-009_SCI_N_20200428094715_20200428094715_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-C-009_SCI_N_20200428094715_20200428094715_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-C-008_SCI_N_20200428094546_20200428094546_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-C-008_SCI_N_20200428094546_20200428094546_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-C-007_SCI_N_20200428094417_20200428094417_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-C-007_SCI_N_20200428094417_20200428094417_0128_B.2BL 已存在
# 下载完成
# 2
# 文件 CE4_GRAS_PCAML-C-006_SCI_N_20200428094248_20200428094248_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-C-006_SCI_N_20200428094248_20200428094248_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-C-005_SCI_N_20200428093658_20200428093658_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-C-005_SCI_N_20200428093658_20200428093658_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-C-004_SCI_N_20200428093529_20200428093529_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-C-004_SCI_N_20200428093529_20200428093529_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-C-003_SCI_N_20200428093400_20200428093400_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-C-003_SCI_N_20200428093400_20200428093400_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-C-002_SCI_N_20200428093231_20200428093231_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-C-002_SCI_N_20200428093231_20200428093231_0128_B.2BL 已存在
# 下载完成
# 3
# 文件 CE4_GRAS_PCAML-C-001_SCI_N_20200428093102_20200428093102_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-C-001_SCI_N_20200428093102_20200428093102_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-C-000_SCI_N_20200428092933_20200428092933_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-C-000_SCI_N_20200428092933_20200428092933_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-011_SCI_N_20200427123145_20200427123145_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-011_SCI_N_20200427123145_20200427123145_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-010_SCI_N_20200427123016_20200427123016_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-010_SCI_N_20200427123016_20200427123016_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-009_SCI_N_20200427122847_20200427122847_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-009_SCI_N_20200427122847_20200427122847_0128_B.2BL 已存在
# 下载完成
# 4
# 文件 CE4_GRAS_PCAML-Q-008_SCI_N_20200427122147_20200427122147_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-008_SCI_N_20200427122147_20200427122147_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-007_SCI_N_20200427122018_20200427122018_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-007_SCI_N_20200427122018_20200427122018_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-006_SCI_N_20200427121849_20200427121849_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-006_SCI_N_20200427121849_20200427121849_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-005_SCI_N_20200427121109_20200427121109_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-005_SCI_N_20200427121109_20200427121109_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-004_SCI_N_20200427120940_20200427120940_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-004_SCI_N_20200427120940_20200427120940_0128_B.2BL 已存在
# 下载完成
# 5
# 文件 CE4_GRAS_PCAML-Q-003_SCI_N_20200427120811_20200427120811_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-003_SCI_N_20200427120811_20200427120811_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-002_SCI_N_20200427120642_20200427120642_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-002_SCI_N_20200427120642_20200427120642_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-001_SCI_N_20200427120513_20200427120513_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-001_SCI_N_20200427120513_20200427120513_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-000_SCI_N_20200427120344_20200427120344_0128_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-000_SCI_N_20200427120344_20200427120344_0128_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-C-002_SCI_N_20200426131257_20200426131257_0127_B.2B 已存在
# 文件 CE4_GRAS_PCAML-C-002_SCI_N_20200426131257_20200426131257_0127_B.2BL 已存在
# 下载完成
# 6
# 文件 CE4_GRAS_PCAML-C-001_SCI_N_20200426131128_20200426131128_0127_B.2B 已存在
# 文件 CE4_GRAS_PCAML-C-001_SCI_N_20200426131128_20200426131128_0127_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-C-000_SCI_N_20200426130411_20200426130411_0127_B.2B 已存在
# 文件 CE4_GRAS_PCAML-C-000_SCI_N_20200426130411_20200426130411_0127_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-082_SCI_N_20200419124455_20200419124455_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-082_SCI_N_20200419124455_20200419124455_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-081_SCI_N_20200419124335_20200419124335_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-081_SCI_N_20200419124335_20200419124335_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-080_SCI_N_20200419124215_20200419124215_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-080_SCI_N_20200419124215_20200419124215_0126_B.2BL 已存在
# 下载完成
# 7
# 文件 CE4_GRAS_PCAML-Q-079_SCI_N_20200419123935_20200419123935_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-079_SCI_N_20200419123935_20200419123935_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-078_SCI_N_20200419123815_20200419123815_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-078_SCI_N_20200419123815_20200419123815_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-077_SCI_N_20200419123655_20200419123655_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-077_SCI_N_20200419123655_20200419123655_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-076_SCI_N_20200419123535_20200419123535_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-076_SCI_N_20200419123535_20200419123535_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-075_SCI_N_20200419123415_20200419123415_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-075_SCI_N_20200419123415_20200419123415_0126_B.2BL 已存在
# 下载完成
# 8
# 文件 CE4_GRAS_PCAML-Q-074_SCI_N_20200419123255_20200419123255_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-074_SCI_N_20200419123255_20200419123255_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-073_SCI_N_20200419123135_20200419123135_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-073_SCI_N_20200419123135_20200419123135_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-072_SCI_N_20200419123015_20200419123015_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-072_SCI_N_20200419123015_20200419123015_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-071_SCI_N_20200419122855_20200419122855_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-071_SCI_N_20200419122855_20200419122855_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-070_SCI_N_20200419122735_20200419122735_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-070_SCI_N_20200419122735_20200419122735_0126_B.2BL 已存在
# 下载完成
# 9
# 文件 CE4_GRAS_PCAML-Q-069_SCI_N_20200419104012_20200419104012_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-069_SCI_N_20200419104012_20200419104012_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-068_SCI_N_20200419103852_20200419103852_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-068_SCI_N_20200419103852_20200419103852_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-067_SCI_N_20200419103732_20200419103732_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-067_SCI_N_20200419103732_20200419103732_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-066_SCI_N_20200419103612_20200419103612_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-066_SCI_N_20200419103612_20200419103612_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-065_SCI_N_20200419103452_20200419103452_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-065_SCI_N_20200419103452_20200419103452_0126_B.2BL 已存在
# 下载完成
# 10
# 文件 CE4_GRAS_PCAML-Q-064_SCI_N_20200419103332_20200419103332_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-064_SCI_N_20200419103332_20200419103332_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-063_SCI_N_20200419103212_20200419103212_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-063_SCI_N_20200419103212_20200419103212_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-062_SCI_N_20200419103052_20200419103052_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-062_SCI_N_20200419103052_20200419103052_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-061_SCI_N_20200419102932_20200419102932_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-061_SCI_N_20200419102932_20200419102932_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-060_SCI_N_20200419102812_20200419102812_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-060_SCI_N_20200419102812_20200419102812_0126_B.2BL 已存在
# 下载完成
# 11
# 文件 CE4_GRAS_PCAML-Q-059_SCI_N_20200419102652_20200419102652_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-059_SCI_N_20200419102652_20200419102652_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-058_SCI_N_20200419102532_20200419102532_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-058_SCI_N_20200419102532_20200419102532_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-057_SCI_N_20200419102412_20200419102412_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-057_SCI_N_20200419102412_20200419102412_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-056_SCI_N_20200419101942_20200419101942_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-056_SCI_N_20200419101942_20200419101942_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-055_SCI_N_20200419101405_20200419101405_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-055_SCI_N_20200419101405_20200419101405_0126_B.2BL 已存在
# 下载完成
# 12
# 文件 CE4_GRAS_PCAML-Q-054_SCI_N_20200419101245_20200419101245_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-054_SCI_N_20200419101245_20200419101245_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-053_SCI_N_20200419101125_20200419101125_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-053_SCI_N_20200419101125_20200419101125_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-052_SCI_N_20200419101005_20200419101005_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-052_SCI_N_20200419101005_20200419101005_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-051_SCI_N_20200419100845_20200419100845_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-051_SCI_N_20200419100845_20200419100845_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-050_SCI_N_20200419100725_20200419100725_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-050_SCI_N_20200419100725_20200419100725_0126_B.2BL 已存在
# 下载完成
# 13
# 文件 CE4_GRAS_PCAML-Q-049_SCI_N_20200419100605_20200419100605_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-049_SCI_N_20200419100605_20200419100605_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-048_SCI_N_20200419100445_20200419100445_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-048_SCI_N_20200419100445_20200419100445_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-047_SCI_N_20200419100325_20200419100325_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-047_SCI_N_20200419100325_20200419100325_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-046_SCI_N_20200419100205_20200419100205_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-046_SCI_N_20200419100205_20200419100205_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-045_SCI_N_20200419100045_20200419100045_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-045_SCI_N_20200419100045_20200419100045_0126_B.2BL 已存在
# 下载完成
# 14
# 文件 CE4_GRAS_PCAML-Q-044_SCI_N_20200419095925_20200419095925_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-044_SCI_N_20200419095925_20200419095925_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-043_SCI_N_20200419095805_20200419095805_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-043_SCI_N_20200419095805_20200419095805_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-042_SCI_N_20200419095645_20200419095645_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-042_SCI_N_20200419095645_20200419095645_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-041_SCI_N_20200419095127_20200419095127_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-041_SCI_N_20200419095127_20200419095127_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-040_SCI_N_20200419095007_20200419095007_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-040_SCI_N_20200419095007_20200419095007_0126_B.2BL 已存在
# 下载完成
# 15
# 文件 CE4_GRAS_PCAML-Q-039_SCI_N_20200419094847_20200419094847_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-039_SCI_N_20200419094847_20200419094847_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-038_SCI_N_20200419094727_20200419094727_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-038_SCI_N_20200419094727_20200419094727_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-037_SCI_N_20200419094607_20200419094607_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-037_SCI_N_20200419094607_20200419094607_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-036_SCI_N_20200419094447_20200419094447_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-036_SCI_N_20200419094447_20200419094447_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-035_SCI_N_20200419094327_20200419094327_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-035_SCI_N_20200419094327_20200419094327_0126_B.2BL 已存在
# 下载完成
# 16
# 文件 CE4_GRAS_PCAML-Q-034_SCI_N_20200419094207_20200419094207_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-034_SCI_N_20200419094207_20200419094207_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-033_SCI_N_20200419094047_20200419094047_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-033_SCI_N_20200419094047_20200419094047_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-032_SCI_N_20200419093927_20200419093927_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-032_SCI_N_20200419093927_20200419093927_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-031_SCI_N_20200419093807_20200419093807_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-031_SCI_N_20200419093807_20200419093807_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-030_SCI_N_20200419093647_20200419093647_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-030_SCI_N_20200419093647_20200419093647_0126_B.2BL 已存在
# 下载完成
# 17
# 文件 CE4_GRAS_PCAML-Q-029_SCI_N_20200419093527_20200419093527_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-029_SCI_N_20200419093527_20200419093527_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-028_SCI_N_20200419093407_20200419093407_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-028_SCI_N_20200419093407_20200419093407_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-027_SCI_N_20200419090710_20200419090710_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-027_SCI_N_20200419090710_20200419090710_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-026_SCI_N_20200419090550_20200419090550_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-026_SCI_N_20200419090550_20200419090550_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-025_SCI_N_20200419090430_20200419090430_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-025_SCI_N_20200419090430_20200419090430_0126_B.2BL 已存在
# 下载完成
# 18
# 文件 CE4_GRAS_PCAML-Q-024_SCI_N_20200419090310_20200419090310_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-024_SCI_N_20200419090310_20200419090310_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-023_SCI_N_20200419090150_20200419090150_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-023_SCI_N_20200419090150_20200419090150_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-022_SCI_N_20200419090030_20200419090030_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-022_SCI_N_20200419090030_20200419090030_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-021_SCI_N_20200419085910_20200419085910_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-021_SCI_N_20200419085910_20200419085910_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-020_SCI_N_20200419085750_20200419085750_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-020_SCI_N_20200419085750_20200419085750_0126_B.2BL 已存在
# 下载完成
# 19
# 文件 CE4_GRAS_PCAML-Q-019_SCI_N_20200419085630_20200419085630_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-019_SCI_N_20200419085630_20200419085630_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-018_SCI_N_20200419085510_20200419085510_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-018_SCI_N_20200419085510_20200419085510_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-017_SCI_N_20200419085350_20200419085350_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-017_SCI_N_20200419085350_20200419085350_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-016_SCI_N_20200419085230_20200419085230_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-016_SCI_N_20200419085230_20200419085230_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-015_SCI_N_20200419085110_20200419085110_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-015_SCI_N_20200419085110_20200419085110_0126_B.2BL 已存在
# 下载完成
# 20
# 文件 CE4_GRAS_PCAML-Q-014_SCI_N_20200419084950_20200419084950_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-014_SCI_N_20200419084950_20200419084950_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-013_SCI_N_20200419084333_20200419084333_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-013_SCI_N_20200419084333_20200419084333_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-012_SCI_N_20200419084213_20200419084213_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-012_SCI_N_20200419084213_20200419084213_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-011_SCI_N_20200419084053_20200419084053_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-011_SCI_N_20200419084053_20200419084053_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-010_SCI_N_20200419083933_20200419083933_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-010_SCI_N_20200419083933_20200419083933_0126_B.2BL 已存在
# 下载完成
# 21
# 文件 CE4_GRAS_PCAML-Q-009_SCI_N_20200419083813_20200419083813_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-009_SCI_N_20200419083813_20200419083813_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-008_SCI_N_20200419083653_20200419083653_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-008_SCI_N_20200419083653_20200419083653_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-007_SCI_N_20200419083533_20200419083533_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-007_SCI_N_20200419083533_20200419083533_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-006_SCI_N_20200419083413_20200419083413_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-006_SCI_N_20200419083413_20200419083413_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-005_SCI_N_20200419083253_20200419083253_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-005_SCI_N_20200419083253_20200419083253_0126_B.2BL 已存在
# 下载完成
# 22
# 文件 CE4_GRAS_PCAML-Q-004_SCI_N_20200419083133_20200419083133_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-004_SCI_N_20200419083133_20200419083133_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-003_SCI_N_20200419083013_20200419083013_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-003_SCI_N_20200419083013_20200419083013_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-002_SCI_N_20200419082853_20200419082853_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-002_SCI_N_20200419082853_20200419082853_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-001_SCI_N_20200419082733_20200419082733_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-001_SCI_N_20200419082733_20200419082733_0126_B.2BL 已存在
# 文件 CE4_GRAS_PCAML-Q-000_SCI_N_20200419082613_20200419082613_0126_B.2B 已存在
# 文件 CE4_GRAS_PCAML-Q-000_SCI_N_20200419082613_20200419082613_0126_B.2BL 已存在
# 下载完成
# 23
# 下载完成

# %%
q = cedm.query_local(qtask='CE4', qpayload='PCAML', qcolor='C', qbatch='*', qseq='*', qext='2BL')
print('查询命中数量：%d\n' % (len(q)))
print(atool.pretty(q))
# Out:
# 查询命中数量：290
#
# [
#     CE4_GRAS_PCAML-C-000_SCI_N_20190104041518_20190104041518_0001_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190110211129_20190110211129_0002_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190112100836_20190112100836_0003_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190208204547_20190208204547_0007_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190228081519_20190228081519_0011_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190429143738_20190429143738_0033_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190508023258_20190508023258_0035_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190510100115_20190510100115_0038_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190708043358_20190708043358_0048_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190729011859_20190729011859_0050_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190806113452_20190806113452_0053_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190826032641_20190826032641_0056_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190827051956_20190827051956_0059_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190827094241_20190827094241_0060_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190903091501_20190903091501_0061_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190905071818_20190905071818_0067_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190925031838_20190925031838_0076_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20191202052108_20191202052108_0097_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20191221020127_20191221020127_0098_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20191221120837_20191221120837_0099_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20200101040020_20200101040020_0111_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20200120075551_20200120075551_0112_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20200130070406_20200130070406_0115_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20200131013127_20200131013127_0116_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20200131025855_20200131025855_0117_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20200131074247_20200131074247_0118_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20200227111928_20200227111928_0121_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20200320091638_20200320091638_0123_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20200329050227_20200329050227_0124_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20200426130411_20200426130411_0127_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20200428092933_20200428092933_0128_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190104041637_20190104041637_0001_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190110211249_20190110211249_0002_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190112100955_20190112100955_0003_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190208204706_20190208204706_0007_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190228081639_20190228081639_0011_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190429143857_20190429143857_0033_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190508023755_20190508023755_0035_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190708043517_20190708043517_0048_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190729012018_20190729012018_0050_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190806113621_20190806113621_0053_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190827094410_20190827094410_0060_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190903112931_20190903112931_0061_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190905071947_20190905071947_0067_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190925031958_20190925031958_0076_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20191202052237_20191202052237_0097_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20191221121006_20191221121006_0099_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20200101040148_20200101040148_0111_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20200120075720_20200120075720_0112_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20200130070535_20200130070535_0115_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20200131013256_20200131013256_0116_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20200131030055_20200131030055_0117_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20200131074416_20200131074416_0118_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20200227112057_20200227112057_0121_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20200320091807_20200320091807_0123_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20200329050356_20200329050356_0124_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20200426131128_20200426131128_0127_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20200428093102_20200428093102_0128_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20190104041756_20190104041756_0001_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20190110211409_20190110211409_0002_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20190112101114_20190112101114_0003_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20190208204825_20190208204825_0007_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20190228081759_20190228081759_0011_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20190429144016_20190429144016_0033_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20190708043636_20190708043636_0048_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20190729012137_20190729012137_0050_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20190806113750_20190806113750_0053_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20190827094539_20190827094539_0060_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20190905072116_20190905072116_0067_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20190925032118_20190925032118_0076_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20191202052406_20191202052406_0097_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20191221121135_20191221121135_0099_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20200120075849_20200120075849_0112_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20200130070704_20200130070704_0115_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20200131013425_20200131013425_0116_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20200227112226_20200227112226_0121_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20200320091936_20200320091936_0123_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20200329050525_20200329050525_0124_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20200426131257_20200426131257_0127_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20200428093231_20200428093231_0128_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20190104042436_20190104042436_0001_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20190110211813_20190110211813_0002_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20190112101505_20190112101505_0003_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20190228081919_20190228081919_0011_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20190429144135_20190429144135_0033_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20190708044006_20190708044006_0048_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20190729012354_20190729012354_0050_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20190806114022_20190806114022_0053_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20190827094707_20190827094707_0060_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20190905072359_20190905072359_0067_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20190925032238_20190925032238_0076_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20191202052535_20191202052535_0097_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20191221121303_20191221121303_0099_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20200120082758_20200120082758_0112_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20200130071543_20200130071543_0115_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20200131014028_20200131014028_0116_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20200227112355_20200227112355_0121_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20200320092105_20200320092105_0123_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20200329050654_20200329050654_0124_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20200428093400_20200428093400_0128_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20190104042555_20190104042555_0001_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20190110211933_20190110211933_0002_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20190112101624_20190112101624_0003_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20190228082039_20190228082039_0011_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20190429144254_20190429144254_0033_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20190708044125_20190708044125_0048_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20190729012513_20190729012513_0050_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20190806114151_20190806114151_0053_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20190827094836_20190827094836_0060_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20190905072528_20190905072528_0067_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20190925032358_20190925032358_0076_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20191202052704_20191202052704_0097_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20191221121432_20191221121432_0099_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20200120082927_20200120082927_0112_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20200130071712_20200130071712_0115_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20200131014157_20200131014157_0116_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20200227112524_20200227112524_0121_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20200320092234_20200320092234_0123_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20200329050823_20200329050823_0124_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20200428093529_20200428093529_0128_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20190104042714_20190104042714_0001_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20190110212053_20190110212053_0002_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20190112101743_20190112101743_0003_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20190228082159_20190228082159_0011_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20190429144413_20190429144413_0033_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20190708044244_20190708044244_0048_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20190729012632_20190729012632_0050_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20190806114320_20190806114320_0053_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20190827095005_20190827095005_0060_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20190905072657_20190905072657_0067_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20190925032518_20190925032518_0076_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20191202052833_20191202052833_0097_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20191221121601_20191221121601_0099_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20200120083056_20200120083056_0112_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20200130071841_20200130071841_0115_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20200131014326_20200131014326_0116_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20200227112653_20200227112653_0121_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20200320092403_20200320092403_0123_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20200329051508_20200329051508_0124_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20200428093658_20200428093658_0128_B.2BL
#     CE4_GRAS_PCAML-C-006_SCI_N_20190104084559_20190104084559_0001_B.2BL
#     CE4_GRAS_PCAML-C-006_SCI_N_20190111034051_20190111034051_0002_B.2BL
#     CE4_GRAS_PCAML-C-006_SCI_N_20190228082319_20190228082319_0011_B.2BL
#     CE4_GRAS_PCAML-C-006_SCI_N_20190429144958_20190429144958_0033_B.2BL
#     CE4_GRAS_PCAML-C-006_SCI_N_20190905081132_20190905081132_0067_B.2BL
#     CE4_GRAS_PCAML-C-006_SCI_N_20190925032638_20190925032638_0076_B.2BL
#     CE4_GRAS_PCAML-C-006_SCI_N_20191202053352_20191202053352_0097_B.2BL
#     CE4_GRAS_PCAML-C-006_SCI_N_20200227112822_20200227112822_0121_B.2BL
#     CE4_GRAS_PCAML-C-006_SCI_N_20200320092758_20200320092758_0123_B.2BL
#     CE4_GRAS_PCAML-C-006_SCI_N_20200329051637_20200329051637_0124_B.2BL
#     CE4_GRAS_PCAML-C-006_SCI_N_20200428094248_20200428094248_0128_B.2BL
#     CE4_GRAS_PCAML-C-007_SCI_N_20190111034211_20190111034211_0002_B.2BL
#     CE4_GRAS_PCAML-C-007_SCI_N_20190228082439_20190228082439_0011_B.2BL
#     CE4_GRAS_PCAML-C-007_SCI_N_20190429145117_20190429145117_0033_B.2BL
#     CE4_GRAS_PCAML-C-007_SCI_N_20190925032758_20190925032758_0076_B.2BL
#     CE4_GRAS_PCAML-C-007_SCI_N_20191202053521_20191202053521_0097_B.2BL
#     CE4_GRAS_PCAML-C-007_SCI_N_20200227112951_20200227112951_0121_B.2BL
#     CE4_GRAS_PCAML-C-007_SCI_N_20200320092927_20200320092927_0123_B.2BL
#     CE4_GRAS_PCAML-C-007_SCI_N_20200329051806_20200329051806_0124_B.2BL
#     CE4_GRAS_PCAML-C-007_SCI_N_20200428094417_20200428094417_0128_B.2BL
#     CE4_GRAS_PCAML-C-008_SCI_N_20190111034331_20190111034331_0002_B.2BL
#     CE4_GRAS_PCAML-C-008_SCI_N_20190228082559_20190228082559_0011_B.2BL
#     CE4_GRAS_PCAML-C-008_SCI_N_20190429145236_20190429145236_0033_B.2BL
#     CE4_GRAS_PCAML-C-008_SCI_N_20190925032918_20190925032918_0076_B.2BL
#     CE4_GRAS_PCAML-C-008_SCI_N_20191202053649_20191202053649_0097_B.2BL
#     CE4_GRAS_PCAML-C-008_SCI_N_20200227113120_20200227113120_0121_B.2BL
#     CE4_GRAS_PCAML-C-008_SCI_N_20200320093056_20200320093056_0123_B.2BL
#     CE4_GRAS_PCAML-C-008_SCI_N_20200329051935_20200329051935_0124_B.2BL
#     CE4_GRAS_PCAML-C-008_SCI_N_20200428094546_20200428094546_0128_B.2BL
#     CE4_GRAS_PCAML-C-009_SCI_N_20190111034644_20190111034644_0002_B.2BL
#     CE4_GRAS_PCAML-C-009_SCI_N_20190228082719_20190228082719_0011_B.2BL
#     CE4_GRAS_PCAML-C-009_SCI_N_20190429145355_20190429145355_0033_B.2BL
#     CE4_GRAS_PCAML-C-009_SCI_N_20190925033038_20190925033038_0076_B.2BL
#     CE4_GRAS_PCAML-C-009_SCI_N_20191202053818_20191202053818_0097_B.2BL
#     CE4_GRAS_PCAML-C-009_SCI_N_20200227113734_20200227113734_0121_B.2BL
#     CE4_GRAS_PCAML-C-009_SCI_N_20200320093225_20200320093225_0123_B.2BL
#     CE4_GRAS_PCAML-C-009_SCI_N_20200329052104_20200329052104_0124_B.2BL
#     CE4_GRAS_PCAML-C-009_SCI_N_20200428094715_20200428094715_0128_B.2BL
#     CE4_GRAS_PCAML-C-010_SCI_N_20190111034804_20190111034804_0002_B.2BL
#     CE4_GRAS_PCAML-C-010_SCI_N_20190228082839_20190228082839_0011_B.2BL
#     CE4_GRAS_PCAML-C-010_SCI_N_20190429145514_20190429145514_0033_B.2BL
#     CE4_GRAS_PCAML-C-010_SCI_N_20190925033158_20190925033158_0076_B.2BL
#     CE4_GRAS_PCAML-C-010_SCI_N_20191202053947_20191202053947_0097_B.2BL
#     CE4_GRAS_PCAML-C-010_SCI_N_20200227113903_20200227113903_0121_B.2BL
#     CE4_GRAS_PCAML-C-010_SCI_N_20200320093354_20200320093354_0123_B.2BL
#     CE4_GRAS_PCAML-C-010_SCI_N_20200329100955_20200329100955_0124_B.2BL
#     CE4_GRAS_PCAML-C-010_SCI_N_20200428094844_20200428094844_0128_B.2BL
#     CE4_GRAS_PCAML-C-011_SCI_N_20190111034924_20190111034924_0002_B.2BL
#     CE4_GRAS_PCAML-C-011_SCI_N_20190228082959_20190228082959_0011_B.2BL
#     CE4_GRAS_PCAML-C-011_SCI_N_20190429145633_20190429145633_0033_B.2BL
#     CE4_GRAS_PCAML-C-011_SCI_N_20190925033318_20190925033318_0076_B.2BL
#     CE4_GRAS_PCAML-C-011_SCI_N_20191202054116_20191202054116_0097_B.2BL
#     CE4_GRAS_PCAML-C-011_SCI_N_20200227114032_20200227114032_0121_B.2BL
#     CE4_GRAS_PCAML-C-011_SCI_N_20200320093523_20200320093523_0123_B.2BL
#     CE4_GRAS_PCAML-C-011_SCI_N_20200329101518_20200329101518_0124_B.2BL
#     CE4_GRAS_PCAML-C-011_SCI_N_20200428095013_20200428095013_0128_B.2BL
#     CE4_GRAS_PCAML-C-012_SCI_N_20190228083119_20190228083119_0011_B.2BL
#     CE4_GRAS_PCAML-C-012_SCI_N_20190925033438_20190925033438_0076_B.2BL
#     CE4_GRAS_PCAML-C-012_SCI_N_20200227114201_20200227114201_0121_B.2BL
#     CE4_GRAS_PCAML-C-013_SCI_N_20190228083239_20190228083239_0011_B.2BL
#     CE4_GRAS_PCAML-C-013_SCI_N_20190925033558_20190925033558_0076_B.2BL
#     CE4_GRAS_PCAML-C-013_SCI_N_20200227114330_20200227114330_0121_B.2BL
#     CE4_GRAS_PCAML-C-014_SCI_N_20190228084235_20190228084235_0011_B.2BL
#     CE4_GRAS_PCAML-C-014_SCI_N_20190925034257_20190925034257_0076_B.2BL
#     CE4_GRAS_PCAML-C-014_SCI_N_20200227114459_20200227114459_0121_B.2BL
#     CE4_GRAS_PCAML-C-015_SCI_N_20190228084355_20190228084355_0011_B.2BL
#     CE4_GRAS_PCAML-C-015_SCI_N_20190925034417_20190925034417_0076_B.2BL
#     CE4_GRAS_PCAML-C-015_SCI_N_20200227114628_20200227114628_0121_B.2BL
#     CE4_GRAS_PCAML-C-016_SCI_N_20190228084515_20190228084515_0011_B.2BL
#     CE4_GRAS_PCAML-C-016_SCI_N_20190925034537_20190925034537_0076_B.2BL
#     CE4_GRAS_PCAML-C-016_SCI_N_20200227114757_20200227114757_0121_B.2BL
#     CE4_GRAS_PCAML-C-017_SCI_N_20190228084635_20190228084635_0011_B.2BL
#     CE4_GRAS_PCAML-C-017_SCI_N_20190925034657_20190925034657_0076_B.2BL
#     CE4_GRAS_PCAML-C-017_SCI_N_20200227114926_20200227114926_0121_B.2BL
#     CE4_GRAS_PCAML-C-018_SCI_N_20190228084755_20190228084755_0011_B.2BL
#     CE4_GRAS_PCAML-C-018_SCI_N_20190925034817_20190925034817_0076_B.2BL
#     CE4_GRAS_PCAML-C-019_SCI_N_20190228084915_20190228084915_0011_B.2BL
#     CE4_GRAS_PCAML-C-019_SCI_N_20190925034937_20190925034937_0076_B.2BL
#     CE4_GRAS_PCAML-C-020_SCI_N_20190228085035_20190228085035_0011_B.2BL
#     CE4_GRAS_PCAML-C-020_SCI_N_20190925035057_20190925035057_0076_B.2BL
#     CE4_GRAS_PCAML-C-021_SCI_N_20190228085155_20190228085155_0011_B.2BL
#     CE4_GRAS_PCAML-C-021_SCI_N_20190925035217_20190925035217_0076_B.2BL
#     CE4_GRAS_PCAML-C-022_SCI_N_20190228085315_20190228085315_0011_B.2BL
#     CE4_GRAS_PCAML-C-022_SCI_N_20190925035337_20190925035337_0076_B.2BL
#     CE4_GRAS_PCAML-C-023_SCI_N_20190228085435_20190228085435_0011_B.2BL
#     CE4_GRAS_PCAML-C-023_SCI_N_20190925035457_20190925035457_0076_B.2BL
#     CE4_GRAS_PCAML-C-024_SCI_N_20190228085555_20190228085555_0011_B.2BL
#     CE4_GRAS_PCAML-C-024_SCI_N_20190925035617_20190925035617_0076_B.2BL
#     CE4_GRAS_PCAML-C-025_SCI_N_20190228085715_20190228085715_0011_B.2BL
#     CE4_GRAS_PCAML-C-025_SCI_N_20190925035737_20190925035737_0076_B.2BL
#     CE4_GRAS_PCAML-C-026_SCI_N_20190228085835_20190228085835_0011_B.2BL
#     CE4_GRAS_PCAML-C-026_SCI_N_20190925035857_20190925035857_0076_B.2BL
#     CE4_GRAS_PCAML-C-027_SCI_N_20190228085955_20190228085955_0011_B.2BL
#     CE4_GRAS_PCAML-C-027_SCI_N_20190925040017_20190925040017_0076_B.2BL
#     CE4_GRAS_PCAML-C-028_SCI_N_20190228091649_20190228091649_0011_B.2BL
#     CE4_GRAS_PCAML-C-028_SCI_N_20190925040933_20190925040933_0076_B.2BL
#     CE4_GRAS_PCAML-C-029_SCI_N_20190228092119_20190228092119_0011_B.2BL
#     CE4_GRAS_PCAML-C-029_SCI_N_20190925041403_20190925041403_0076_B.2BL
#     CE4_GRAS_PCAML-C-030_SCI_N_20190228092239_20190228092239_0011_B.2BL
#     CE4_GRAS_PCAML-C-030_SCI_N_20190925041523_20190925041523_0076_B.2BL
#     CE4_GRAS_PCAML-C-031_SCI_N_20190228092359_20190228092359_0011_B.2BL
#     CE4_GRAS_PCAML-C-031_SCI_N_20190925041643_20190925041643_0076_B.2BL
#     CE4_GRAS_PCAML-C-032_SCI_N_20190228092519_20190228092519_0011_B.2BL
#     CE4_GRAS_PCAML-C-032_SCI_N_20190925041803_20190925041803_0076_B.2BL
#     CE4_GRAS_PCAML-C-033_SCI_N_20190228092639_20190228092639_0011_B.2BL
#     CE4_GRAS_PCAML-C-033_SCI_N_20190925041923_20190925041923_0076_B.2BL
#     CE4_GRAS_PCAML-C-034_SCI_N_20190228092759_20190228092759_0011_B.2BL
#     CE4_GRAS_PCAML-C-034_SCI_N_20190925042043_20190925042043_0076_B.2BL
#     CE4_GRAS_PCAML-C-035_SCI_N_20190228092919_20190228092919_0011_B.2BL
#     CE4_GRAS_PCAML-C-035_SCI_N_20190925042203_20190925042203_0076_B.2BL
#     CE4_GRAS_PCAML-C-036_SCI_N_20190228093039_20190228093039_0011_B.2BL
#     CE4_GRAS_PCAML-C-036_SCI_N_20190925042323_20190925042323_0076_B.2BL
#     CE4_GRAS_PCAML-C-037_SCI_N_20190228093159_20190228093159_0011_B.2BL
#     CE4_GRAS_PCAML-C-037_SCI_N_20190925042443_20190925042443_0076_B.2BL
#     CE4_GRAS_PCAML-C-038_SCI_N_20190228093319_20190228093319_0011_B.2BL
#     CE4_GRAS_PCAML-C-038_SCI_N_20190925042603_20190925042603_0076_B.2BL
#     CE4_GRAS_PCAML-C-039_SCI_N_20190228093439_20190228093439_0011_B.2BL
#     CE4_GRAS_PCAML-C-039_SCI_N_20190925042723_20190925042723_0076_B.2BL
#     CE4_GRAS_PCAML-C-040_SCI_N_20190228093559_20190228093559_0011_B.2BL
#     CE4_GRAS_PCAML-C-040_SCI_N_20190925042843_20190925042843_0076_B.2BL
#     CE4_GRAS_PCAML-C-041_SCI_N_20190228093719_20190228093719_0011_B.2BL
#     CE4_GRAS_PCAML-C-041_SCI_N_20190925043003_20190925043003_0076_B.2BL
#     CE4_GRAS_PCAML-C-042_SCI_N_20190228094713_20190228094713_0011_B.2BL
#     CE4_GRAS_PCAML-C-042_SCI_N_20190925044057_20190925044057_0076_B.2BL
#     CE4_GRAS_PCAML-C-043_SCI_N_20190228094833_20190228094833_0011_B.2BL
#     CE4_GRAS_PCAML-C-043_SCI_N_20190925044217_20190925044217_0076_B.2BL
#     CE4_GRAS_PCAML-C-044_SCI_N_20190228094953_20190228094953_0011_B.2BL
#     CE4_GRAS_PCAML-C-044_SCI_N_20190925044337_20190925044337_0076_B.2BL
#     CE4_GRAS_PCAML-C-045_SCI_N_20190228095113_20190228095113_0011_B.2BL
#     CE4_GRAS_PCAML-C-045_SCI_N_20190925044457_20190925044457_0076_B.2BL
#     CE4_GRAS_PCAML-C-046_SCI_N_20190228095233_20190228095233_0011_B.2BL
#     CE4_GRAS_PCAML-C-046_SCI_N_20190925044617_20190925044617_0076_B.2BL
#     CE4_GRAS_PCAML-C-047_SCI_N_20190228095353_20190228095353_0011_B.2BL
#     CE4_GRAS_PCAML-C-047_SCI_N_20190925044737_20190925044737_0076_B.2BL
#     CE4_GRAS_PCAML-C-048_SCI_N_20190228095513_20190228095513_0011_B.2BL
#     CE4_GRAS_PCAML-C-048_SCI_N_20190925044857_20190925044857_0076_B.2BL
#     CE4_GRAS_PCAML-C-049_SCI_N_20190228095633_20190228095633_0011_B.2BL
#     CE4_GRAS_PCAML-C-049_SCI_N_20190925045017_20190925045017_0076_B.2BL
#     CE4_GRAS_PCAML-C-050_SCI_N_20190228095753_20190228095753_0011_B.2BL
#     CE4_GRAS_PCAML-C-050_SCI_N_20190925045137_20190925045137_0076_B.2BL
#     CE4_GRAS_PCAML-C-051_SCI_N_20190228095913_20190228095913_0011_B.2BL
#     CE4_GRAS_PCAML-C-051_SCI_N_20190925045257_20190925045257_0076_B.2BL
#     CE4_GRAS_PCAML-C-052_SCI_N_20190228100033_20190228100033_0011_B.2BL
#     CE4_GRAS_PCAML-C-052_SCI_N_20190925045417_20190925045417_0076_B.2BL
#     CE4_GRAS_PCAML-C-053_SCI_N_20190228100153_20190228100153_0011_B.2BL
#     CE4_GRAS_PCAML-C-053_SCI_N_20190925045537_20190925045537_0076_B.2BL
#     CE4_GRAS_PCAML-C-054_SCI_N_20190228100313_20190228100313_0011_B.2BL
#     CE4_GRAS_PCAML-C-054_SCI_N_20190925045657_20190925045657_0076_B.2BL
#     CE4_GRAS_PCAML-C-055_SCI_N_20190228100433_20190228100433_0011_B.2BL
#     CE4_GRAS_PCAML-C-055_SCI_N_20190925045817_20190925045817_0076_B.2BL
#
# ]

# %%
q4 = cedm.query_local(qtask='CE4', qpayload='PCAML', qcolor='C', qbatch='0007', qseq='*', qext='2BL')
q1 = cedm.query_local(qtask='CE4', qpayload='PCAML', qcolor='C', qbatch='0033', qseq='*', qext='2BL')
q2 = cedm.query_local(qtask='CE4', qpayload='PCAML', qcolor='C', qbatch='0035', qseq='*', qext='2BL')
q3 = cedm.query_local(qtask='CE4', qpayload='PCAML', qcolor='C', qbatch='0038', qseq='*', qext='2BL')
leftlist = q4+q1+q2+q3
print('查询命中数量：%d\n' % (len(leftlist)))
print(atool.pretty(leftlist))

q4 = cedm.query_local(qtask='CE4', qpayload='PCAMR', qcolor='C', qbatch='0007', qseq='*', qext='2BL')
q1 = cedm.query_local(qtask='CE4', qpayload='PCAMR', qcolor='C', qbatch='0033', qseq='*', qext='2BL')
q2 = cedm.query_local(qtask='CE4', qpayload='PCAMR', qcolor='C', qbatch='0035', qseq='*', qext='2BL')
q3 = cedm.query_local(qtask='CE4', qpayload='PCAMR', qcolor='C', qbatch='0038', qseq='*', qext='2BL')
rightlist = q4+q1+q2+q3
print('查询命中数量：%d\n' % (len(rightlist)))
print(atool.pretty(rightlist))
# Out:
# 查询命中数量：18
#
# [
#     CE4_GRAS_PCAML-C-000_SCI_N_20190208204547_20190208204547_0007_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190208204706_20190208204706_0007_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20190208204825_20190208204825_0007_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190429143738_20190429143738_0033_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190429143857_20190429143857_0033_B.2BL
#     CE4_GRAS_PCAML-C-002_SCI_N_20190429144016_20190429144016_0033_B.2BL
#     CE4_GRAS_PCAML-C-003_SCI_N_20190429144135_20190429144135_0033_B.2BL
#     CE4_GRAS_PCAML-C-004_SCI_N_20190429144254_20190429144254_0033_B.2BL
#     CE4_GRAS_PCAML-C-005_SCI_N_20190429144413_20190429144413_0033_B.2BL
#     CE4_GRAS_PCAML-C-006_SCI_N_20190429144958_20190429144958_0033_B.2BL
#     CE4_GRAS_PCAML-C-007_SCI_N_20190429145117_20190429145117_0033_B.2BL
#     CE4_GRAS_PCAML-C-008_SCI_N_20190429145236_20190429145236_0033_B.2BL
#     CE4_GRAS_PCAML-C-009_SCI_N_20190429145355_20190429145355_0033_B.2BL
#     CE4_GRAS_PCAML-C-010_SCI_N_20190429145514_20190429145514_0033_B.2BL
#     CE4_GRAS_PCAML-C-011_SCI_N_20190429145633_20190429145633_0033_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190508023258_20190508023258_0035_B.2BL
#     CE4_GRAS_PCAML-C-001_SCI_N_20190508023755_20190508023755_0035_B.2BL
#     CE4_GRAS_PCAML-C-000_SCI_N_20190510100115_20190510100115_0038_B.2BL
#
# ]
#
# 查询命中数量：18
#
# [
#     CE4_GRAS_PCAMR-C-000_SCI_N_20190208204531_20190208204531_0007_B.2BL
#     CE4_GRAS_PCAMR-C-001_SCI_N_20190208204650_20190208204650_0007_B.2BL
#     CE4_GRAS_PCAMR-C-002_SCI_N_20190208204809_20190208204809_0007_B.2BL
#     CE4_GRAS_PCAMR-C-000_SCI_N_20190429143722_20190429143722_0033_B.2BL
#     CE4_GRAS_PCAMR-C-001_SCI_N_20190429143841_20190429143841_0033_B.2BL
#     CE4_GRAS_PCAMR-C-002_SCI_N_20190429144000_20190429144000_0033_B.2BL
#     CE4_GRAS_PCAMR-C-003_SCI_N_20190429144119_20190429144119_0033_B.2BL
#     CE4_GRAS_PCAMR-C-004_SCI_N_20190429144238_20190429144238_0033_B.2BL
#     CE4_GRAS_PCAMR-C-005_SCI_N_20190429144357_20190429144357_0033_B.2BL
#     CE4_GRAS_PCAMR-C-006_SCI_N_20190429144942_20190429144942_0033_B.2BL
#     CE4_GRAS_PCAMR-C-007_SCI_N_20190429145101_20190429145101_0033_B.2BL
#     CE4_GRAS_PCAMR-C-008_SCI_N_20190429145220_20190429145220_0033_B.2BL
#     CE4_GRAS_PCAMR-C-009_SCI_N_20190429145339_20190429145339_0033_B.2BL
#     CE4_GRAS_PCAMR-C-010_SCI_N_20190429145458_20190429145458_0033_B.2BL
#     CE4_GRAS_PCAMR-C-011_SCI_N_20190429145617_20190429145617_0033_B.2BL
#     CE4_GRAS_PCAMR-C-000_SCI_N_20190508023242_20190508023242_0035_B.2BL
#     CE4_GRAS_PCAMR-C-001_SCI_N_20190508023739_20190508023739_0035_B.2BL
#     CE4_GRAS_PCAMR-C-000_SCI_N_20190510100059_20190510100059_0038_B.2BL
#
# ]

# %%
# %%time
cedm.convert_SBS_from_list(leftlist, rightlist, 'data', 'png')
# Out:
# Processing label: data/CE4_GRAS_PCAML-C-000_SCI_N_20190429143738_20190429143738_0033_B.2BL
# 2021-05-19 00:53:43 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAML-C-000_SCI_N_20190429143738_20190429143738_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:53:43 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.348695910986 0.805331361145
# Processing label: data/CE4_GRAS_PCAMR-C-000_SCI_N_20190429143722_20190429143722_0033_B.2BL
# 2021-05-19 00:53:44 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAMR-C-000_SCI_N_20190429143722_20190429143722_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:53:45 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.328182198208 0.80304019261
# Processing label: data/CE4_GRAS_PCAML-C-001_SCI_N_20190429143857_20190429143857_0033_B.2BL
# 2021-05-19 00:53:46 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAML-C-001_SCI_N_20190429143857_20190429143857_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:53:46 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.396248342435 0.805045432268
# Processing label: data/CE4_GRAS_PCAMR-C-001_SCI_N_20190429143841_20190429143841_0033_B.2BL
# 2021-05-19 00:53:47 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAMR-C-001_SCI_N_20190429143841_20190429143841_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:53:47 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.411074473121 0.794371015884
# Processing label: data/CE4_GRAS_PCAML-C-002_SCI_N_20190429144016_20190429144016_0033_B.2BL
# 2021-05-19 00:53:49 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAML-C-002_SCI_N_20190429144016_20190429144016_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:53:49 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.363172548991 0.807044147751
# Processing label: data/CE4_GRAS_PCAMR-C-002_SCI_N_20190429144000_20190429144000_0033_B.2BL
# 2021-05-19 00:53:50 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAMR-C-002_SCI_N_20190429144000_20190429144000_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:53:50 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.381446895537 0.801172291762
# Processing label: data/CE4_GRAS_PCAML-C-003_SCI_N_20190429144135_20190429144135_0033_B.2BL
# 2021-05-19 00:53:51 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAML-C-003_SCI_N_20190429144135_20190429144135_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:53:51 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.457078389341 0.737605882131
# Processing label: data/CE4_GRAS_PCAMR-C-003_SCI_N_20190429144119_20190429144119_0033_B.2BL
# 2021-05-19 00:53:53 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAMR-C-003_SCI_N_20190429144119_20190429144119_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:53:53 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.45766895405 0.733745125386
# Processing label: data/CE4_GRAS_PCAML-C-004_SCI_N_20190429144254_20190429144254_0033_B.2BL
# 2021-05-19 00:53:54 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAML-C-004_SCI_N_20190429144254_20190429144254_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:53:54 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.48221488862 0.729857728914
# Processing label: data/CE4_GRAS_PCAMR-C-004_SCI_N_20190429144238_20190429144238_0033_B.2BL
# 2021-05-19 00:53:55 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAMR-C-004_SCI_N_20190429144238_20190429144238_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:53:55 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.519113093096 0.741758874105
# Processing label: data/CE4_GRAS_PCAML-C-005_SCI_N_20190429144413_20190429144413_0033_B.2BL
# 2021-05-19 00:53:57 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAML-C-005_SCI_N_20190429144413_20190429144413_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:53:57 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.153959595257 0.713027054748
# Processing label: data/CE4_GRAS_PCAMR-C-005_SCI_N_20190429144357_20190429144357_0033_B.2BL
# 2021-05-19 00:53:58 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAMR-C-005_SCI_N_20190429144357_20190429144357_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:53:58 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.177027350375 0.712524188785
# Processing label: data/CE4_GRAS_PCAML-C-006_SCI_N_20190429144958_20190429144958_0033_B.2BL
# 2021-05-19 00:53:59 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAML-C-006_SCI_N_20190429144958_20190429144958_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:53:59 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.0918042598758 0.813001718058
# Processing label: data/CE4_GRAS_PCAMR-C-006_SCI_N_20190429144942_20190429144942_0033_B.2BL
# 2021-05-19 00:54:00 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAMR-C-006_SCI_N_20190429144942_20190429144942_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:00 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.107590454748 0.843448356341
# Processing label: data/CE4_GRAS_PCAML-C-007_SCI_N_20190429145117_20190429145117_0033_B.2BL
# 2021-05-19 00:54:01 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAML-C-007_SCI_N_20190429145117_20190429145117_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:01 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.11049941568 0.806045601931
# Processing label: data/CE4_GRAS_PCAMR-C-007_SCI_N_20190429145101_20190429145101_0033_B.2BL
# 2021-05-19 00:54:03 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAMR-C-007_SCI_N_20190429145101_20190429145101_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:03 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.324610945061 0.80647374856
# Processing label: data/CE4_GRAS_PCAML-C-008_SCI_N_20190429145236_20190429145236_0033_B.2BL
# 2021-05-19 00:54:04 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAML-C-008_SCI_N_20190429145236_20190429145236_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:04 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.446280715484 0.769412292169
# Processing label: data/CE4_GRAS_PCAMR-C-008_SCI_N_20190429145220_20190429145220_0033_B.2BL
# 2021-05-19 00:54:05 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAMR-C-008_SCI_N_20190429145220_20190429145220_0033_B.2BL
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:05 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.450518203773 0.766369939398
# Processing label: data/CE4_GRAS_PCAML-C-009_SCI_N_20190429145355_20190429145355_0033_B.2BL
# 2021-05-19 00:54:06 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAML-C-009_SCI_N_20190429145355_20190429145355_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:06 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.41675741831 0.799731553274
# Processing label: data/CE4_GRAS_PCAMR-C-009_SCI_N_20190429145339_20190429145339_0033_B.2BL
# 2021-05-19 00:54:08 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAMR-C-009_SCI_N_20190429145339_20190429145339_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:08 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.419069814727 0.805902820136
# Processing label: data/CE4_GRAS_PCAML-C-010_SCI_N_20190429145514_20190429145514_0033_B.2BL
# 2021-05-19 00:54:09 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAML-C-010_SCI_N_20190429145514_20190429145514_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:09 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.384755893334 0.822249608164
# Processing label: data/CE4_GRAS_PCAMR-C-010_SCI_N_20190429145458_20190429145458_0033_B.2BL
# 2021-05-19 00:54:10 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAMR-C-010_SCI_N_20190429145458_20190429145458_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:10 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.387305659079 0.819461668393
# Processing label: data/CE4_GRAS_PCAML-C-011_SCI_N_20190429145633_20190429145633_0033_B.2BL
# 2021-05-19 00:54:11 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAML-C-011_SCI_N_20190429145633_20190429145633_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:11 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.351975410873 0.826960842881
# Processing label: data/CE4_GRAS_PCAMR-C-011_SCI_N_20190429145617_20190429145617_0033_B.2BL
# 2021-05-19 00:54:13 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAMR-C-011_SCI_N_20190429145617_20190429145617_0033_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:13 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.336912499089 0.825578847672
# Processing label: data/CE4_GRAS_PCAML-C-000_SCI_N_20190508023258_20190508023258_0035_B.2BL
# 2021-05-19 00:54:14 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAML-C-000_SCI_N_20190508023258_20190508023258_0035_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:14 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.189115793993 0.832732396055
# Processing label: data/CE4_GRAS_PCAMR-C-000_SCI_N_20190508023242_20190508023242_0035_B.2BL
# 2021-05-19 00:54:15 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAMR-C-000_SCI_N_20190508023242_20190508023242_0035_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:15 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.158049439477 0.873671791617
# Processing label: data/CE4_GRAS_PCAML-C-001_SCI_N_20190508023755_20190508023755_0035_B.2BL
# 2021-05-19 00:54:16 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAML-C-001_SCI_N_20190508023755_20190508023755_0035_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:16 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.0189442815249 0.704925144028
# Processing label: data/CE4_GRAS_PCAMR-C-001_SCI_N_20190508023739_20190508023739_0035_B.2BL
# 2021-05-19 00:54:18 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAMR-C-001_SCI_N_20190508023739_20190508023739_0035_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:18 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.00631476050831 0.713027054748
# Processing label: data/CE4_GRAS_PCAML-C-000_SCI_N_20190510100115_20190510100115_0038_B.2BL
# 2021-05-19 00:54:19 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAML-C-000_SCI_N_20190510100115_20190510100115_0038_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:19 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.32773834045 0.992116778192
# Processing label: data/CE4_GRAS_PCAMR-C-000_SCI_N_20190510100059_20190510100059_0038_B.2BL
# 2021-05-19 00:54:20 core.py [line:189] INFO: Processing label: data/CE4_GRAS_PCAMR-C-000_SCI_N_20190510100059_20190510100059_0038_B.2BL
#
# Now processing a Array_2D_Image structure: ARRAY_0
# 2021-05-19 00:54:20 core.py [line:304] INFO: Now processing a Array_2D_Image structure: ARRAY_0
#
# 提取原始数据并归一化 (1728, 2352) 2
# CFA上色（de-bayer） (1728, 2352, 3) 3
# 直方图拉伸 0.303580723361 1.0
